# %%
import numpy as numpy
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
lr_model = linear_model.LinearRegression()

# %%
x = [[164], [179], [180], [170]]
y = [53, 63, 88, 59]

# %%
lr_model.fit(x, y)
# Out:
# LinearRegression()

# %%
indata = [[169],[186]]
print(lr_model.predict(indata))
# Out:
# [59.08011445 85.75965665]

# %%
plt.scatter(x, y)
